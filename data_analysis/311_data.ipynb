# %%
import pandas as pd

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

orig_data = pd.read_csv('./311_Service_Requests_from_2010_to_Present.csv', nrows=100000, parse_dates=['Created Date'])

# %%
complaints = orig_data['Complaint Type'].unique()

# %%
noise_types = [complaint for complaint in complaints if 'noise' in complaint.lower()]

# %%
noise_types
# Out:
# ['Noise - House of Worship',
#  'Noise - Commercial',
#  'Noise - Street/Sidewalk',
#  'Noise - Vehicle',
#  'Noise - Park',
#  'Noise',
#  'Noise - Helicopter',
#  'Collection Truck Noise']

# %%
noise_complaints = orig_data[orig_data['Complaint Type'].isin(noise_types)]

# %%
noise_complaints.sort(ascending=[1, 0])
noise_complaints.set_index('Created Date')
# Out:
#                      Unique Key             Closed Date Agency                       Agency Name            Complaint Type        Descriptor        Location Type Incident Zip              Incident Address               Street Name        Cross Street 1      Cross Street 2 Intersection Street 1 Intersection Street 2  Address Type                 City Landmark Facility Type    Status                Due Date Resolution Action Updated Date   Community Board        Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name   Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude                                  Location
# ...

# %%
noise_complaints.ix['2013':'2014']
# from datetime import datetime as dt

# start = noise_complaints.index.searchsorted(dt(2014, 1, 1))
# Out:
# Empty DataFrame
# Columns: [Unique Key, Created Date, Closed Date, Agency, Agency Name, Complaint Type, Descriptor, Location Type, Incident Zip, Incident Address, Street Name, Cross Street 1, Cross Street 2, Intersection Street 1, Intersection Street 2, Address Type, City, Landmark, Facility Type, Status, Due Date, Resolution Action Updated Date, Community Board, Borough, X Coordinate (State Plane), Y Coordinate (State Plane), Park Facility Name, Park Borough, School Name, School Number, School Region, School Code, School Phone Number, School Address, School City, School State, School Zip, School Not Found, School or Citywide Complaint, Vehicle Type, Taxi Company Borough, Taxi Pick Up Location, Bridge Highway Name, Bridge Highway Direction, Road Ramp, Bridge Highway Segment, Garage Lot Name, Ferry Direction, Ferry Terminal Name, Latitude, Longitude, Location]
# Index: []

# %%
pd.datetime(2014, 1, 1)
# Out:
# datetime.datetime(2014, 1, 1, 0, 0)
